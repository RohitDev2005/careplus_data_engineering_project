# %%
import pandas as pd
df = pd.read_parquet("support_logs_2025-07-01.parquet")
print(df.dtypes)
# Out:
# timestamp        datetime64[ms]
# log_level                object
# component                object
# ticket_id                object
# session_id               object
# ip                       object
# response_time             int64
# cpu                     float64
# event_type               object
# error                      bool
# user_agent               object
# message                  object
# debug                    object
# dtype: object

# %%
df.head()
# Out:
#             timestamp log_level                        component   ticket_id  \
# 0 2025-07-01 00:21:00      INFO  careplus.support.GenericService  TCK0701000
# 1 2025-07-01 00:41:00      INFO  careplus.support.GenericService  TCK0701000
# 2 2025-07-01 01:44:00     DEBUG  careplus.support.GenericService  TCK0701001
# 3 2025-07-01 01:49:00     DEBUG  careplus.support.GenericService  TCK0701001
# 4 2025-07-01 01:50:00      INFO  careplus.support.GenericService  TCK0701000
#
#         session_id             ip  response_time    cpu     event_type  error  \
# 0  sess_TCK0701000   60.130.155.7           1269  27.64  generic_event  False
# 1  sess_TCK0701000   58.36.189.27           1505  57.24  generic_event  False
# 2  sess_TCK0701001  181.18.12.170            586  78.43  generic_event  False
# 3  sess_TCK0701001  163.214.94.42            878  63.61  generic_event  False
# 4  sess_TCK0701000  155.68.207.12           1614  87.85  generic_event  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      89 non-null     datetime64[ms]
#  1   log_level      89 non-null     object
#  2   component      89 non-null     object
#  3   ticket_id      89 non-null     object
#  4   session_id     89 non-null     object
#  5   ip             89 non-null     object
#  6   response_time  89 non-null     int64
#  7   cpu            89 non-null     float64
#  8   event_type     89 non-null     object
#  9   error          89 non-null     bool
#  10  user_agent     89 non-null     object
#  11  message        89 non-null     object
#  12  debug          89 non-null     object
# dtypes: bool(1), datetime64[ms](1), float64(1), int64(1), object(9)
# memory usage: 8.6+ KB

# %%
df.shape
# Out:
# (89, 13)
