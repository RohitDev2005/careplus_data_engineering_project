# %%
import pandas as pd

file_path = "run-1785596212262-part-block-0-r-00000-snappy.parquet"

df = pd.read_parquet(file_path)

display(df.head())
# Out:
#     ticket_id          created_at         resolved_at   agent priority  \
# 0  TCK0701000 2025-07-01 00:13:00                 NaT   Sneha   Medium
# 1  TCK0701001 2025-07-01 01:24:00 2025-07-01 02:47:00   Kavya   Medium
# 2  TCK0701002 2025-07-01 01:49:00 2025-07-01 19:25:00   Rohit      Low
# 3  TCK0701004 2025-07-01 03:03:00 2025-07-02 11:00:00  Ananya     High
# 4  TCK0701005 2025-07-01 03:07:00 2025-07-02 00:35:00   Arjun     High
#
#    num_interactions   issue_category   channel    status
# 0                 7  Payment Failure      Chat      Open
# 1                 8   Account Locked  Web Form  Resolved
# 2                 3       Bug Report  Web Form  Resolved
# 3                 5       Bug Report      Chat  Resolved
# 4                 1       Bug Report     Email  Resolved

# %%
print("Shape:", df.shape)
# Out:
# Shape: (27, 9)

# %%
print(df.dtypes)
# Out:
# ticket_id                   object
# created_at          datetime64[ns]
# resolved_at         datetime64[ns]
# agent                       object
# priority                    object
# num_interactions             int32
# issue_category              object
# channel                     object
# status                      object
# dtype: object
